# %% [markdown]
# ## Desafio 1 da Trilha de Visão Computacional
#
# Nesse desafio você irá implementar uma solução simples para borrar o fundo de uma imagem como uma pessoa, semelhante ao que aplicativos de vídeo chamadas fazem hoje em dia.
#
# Para isso você deverá seguir os pasos desse documento atentamente.

# %% [markdown]
# ### Instalação e Importação da Biblioteca

# %%
# !pip install opencv-python matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp312-cp312-win_amd64.whl.metadata (52 kB)
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/52.8 kB ? eta -:--:--
#      -------------------------------------- - 51.2/52.8 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 52.8/52.8 kB 676.1 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=2 in c:\users\joaor\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from opencv-python) (2.4.4)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp312-cp312-win_amd64.whl.metadata (121 kB)
#      ---------------------------------------- 0.0/121.0 kB ? eta -:--:--
#      ----------------------------------- -- 112.6/121.0 kB 3.3 MB/s eta 0:00:01
#      -------------------------------------- 121.0/121.0 kB 1.8 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\joaor\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.2.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\joaor\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\joaor\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.2/40.2 MB 5.1 MB/s eta 0:00:08
#     --------------------------------------- 0.6/40.2 MB 7.0 MB/s eta 0:00:06
#    - -------------------------------------- 1.2/40.2 MB 10.6 MB/s eta 0:00:04
#    - -------------------------------------- 1.8/40.2 MB 11.5 MB/s eta 0:00:04
#    -- ------------------------------------- 2.5/40.2 MB 12.3 MB/s eta 0:00:04
#    --- ------------------------------------ 3.1/40.2 MB 13.2 MB/s eta 0:00:03
#    --- ------------------------------------ 3.5/40.2 MB 12.4 MB/s eta 0:00:03
#    --- ------------------------------------ 3.9/40.2 MB 12.0 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.9/40.2 MB 12.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.5/40.2 MB 13.1 MB/s eta 0:00:03
#    ------ --------------------------------- 6.3/40.2 MB 13.8 MB/s eta 0:00:03
#    ------ --------------------------------- 6.8/40.2 MB 14.0 MB/s eta 0:00:03
#    ------- -------------------------------- 7.5/40.2 MB 13.6 MB/s eta 0:00:03
#    -------- ------------------------------- 8.1/40.2 MB 14.0 MB/s eta 0:00:03
#    -------- ------------------------------- 8.7/40.2 MB 13.9 MB/s eta 0:00:03
#    --------- ------------------------------ 9.5/40.2 MB 14.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 10.2/40.2 MB 14.5 MB/s eta 0:00:03
#    ---------- ----------------------------- 10.9/40.2 MB 15.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 11.8/40.2 MB 15.6 MB/s eta 0:00:02
#    ------------ --------------------------- 12.7/40.2 MB 16.0 MB/s eta 0:00:02
#    ------------- -------------------------- 13.5/40.2 MB 16.4 MB/s eta 0:00:02
#    -------------- ------------------------- 14.5/40.2 MB 16.8 MB/s eta 0:00:02
#    --------------- ------------------------ 15.2/40.2 MB 17.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 16.3/40.2 MB 17.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 16.9/40.2 MB 17.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 17.8/40.2 MB 19.3 MB/s eta 0:00:02
#    ------------------ --------------------- 18.6/40.2 MB 19.3 MB/s eta 0:00:02
#    ------------------- -------------------- 19.5/40.2 MB 19.3 MB/s eta 0:00:02
#    -------------------- ------------------- 20.1/40.2 MB 19.3 MB/s eta 0:00:02
#    -------------------- ------------------- 21.1/40.2 MB 19.8 MB/s eta 0:00:01
#    --------------------- ------------------ 21.9/40.2 MB 19.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 22.8/40.2 MB 20.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 23.6/40.2 MB 19.8 MB/s eta 0:00:01
#    ------------------------ --------------- 24.5/40.2 MB 19.8 MB/s eta 0:00:01
#    ------------------------- -------------- 25.2/40.2 MB 19.9 MB/s eta 0:00:01
#    -------------------------- ------------- 26.3/40.2 MB 20.5 MB/s eta 0:00:01
#    --------------------------- ------------ 27.2/40.2 MB 20.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 28.2/40.2 MB 20.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 29.0/40.2 MB 20.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 30.0/40.2 MB 21.1 MB/s eta 0:00:01
#    ------------------------------ --------- 31.0/40.2 MB 21.1 MB/s eta 0:00:01
#    ------------------------------- -------- 32.0/40.2 MB 21.1 MB/s eta 0:00:01
#    -------------------------------- ------- 32.8/40.2 MB 21.8 MB/s eta 0:00:01
#    --------------------------------- ------ 33.8/40.2 MB 21.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 34.7/40.2 MB 21.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 35.4/40.2 MB 21.8 MB/s eta 0:00:01
#    ------------------------------------ --- 36.4/40.2 MB 21.8 MB/s eta 0:00:01
#    ------------------------------------ --- 37.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ------------------------------------- -- 37.9/40.2 MB 21.1 MB/s eta 0:00:01
#    -------------------------------------- - 38.8/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.0/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 4.3 MB/s eta 0:00:00
# Downloading matplotlib-3.10.9-cp312-cp312-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.9/8.2 MB 28.4 MB/s eta 0:00:01
#    --------- ------------------------------ 2.0/8.2 MB 18.2 MB/s eta 0:00:01
#    ------------- -------------------------- 2.8/8.2 MB 20.0 MB/s eta 0:00:01
#    --------------------- ------------------ 4.3/8.2 MB 21.2 MB/s eta 0:00:01
#    -------------------------- ------------- 5.3/8.2 MB 21.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.1/8.2 MB 21.8 MB/s eta 0:00:01
#    --------------------------------- ------ 6.9/8.2 MB 21.0 MB/s eta 0:00:01
#    ------------------------------------ --- 7.6/8.2 MB 20.2 MB/s eta 0:00:01
#    ---------------------------------------  8.2/8.2 MB 20.2 MB/s eta 0:00:01
#    ---------------------------------------  8.2/8.2 MB 20.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 17.5 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
#    ---------------------------------------- 0.0/226.6 kB ? eta -:--:--
#    ---------------------------------------- 226.6/226.6 kB 7.0 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    --------------- ------------------------ 0.9/2.3 MB 28.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.7/2.3 MB 21.8 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 21.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 15.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl (73 kB)
#    ---------------------------------------- 0.0/73.6 kB ? eta -:--:--
#    ---------------------------------------- 73.6/73.6 kB 2.0 MB/s eta 0:00:00
# Using cached pillow-12.2.0-cp312-cp312-win_amd64.whl (7.1 MB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#    ---------------------------------------- 0.0/122.8 kB ? eta -:--:--
#    ---------------------------------------- 122.8/122.8 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, opencv-python, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.10.9 opencv-python-4.13.0.92 pillow-12.2.0 pyparsing-3.3.2
# [notice] A new release of pip is available: 23.3.2 -> 26.1.2
# [notice] To update, run: C:\Users\joaor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import cv2
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### Ler Imagens

# %%
image_bgr = cv2.imread("desafio_1.jpeg")
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)

# %% [markdown]
# ### Transformar em Escala de Cinza

# %%
image_gray = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray, cmap="gray")

# %% [markdown]
# ### Detectar as Faces
#
# Para isso iremos utilizar o `haar cascade` um método de detecção de faces clásscio. Mais detalhes sobre o `haar cascade` [aqui](https://docs.opencv.org/3.4/db/d28/tutorial_cascade_classifier.html)

# %%
detec = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
face = detec.detectMultiScale(image_gray, 1.3, 3)
copy_image_rgb = image_rgb.copy()
padding = 100
for (x, y, larg, alt) in face: #Desenhar o retângulo
    ret = cv2.rectangle(copy_image_rgb, (x, y), (x + larg, y + alt), (0, 255, 0), 3)
    y, height = max(0, y-padding), min(y+alt+padding, image_rgb.shape[0])
    x, width = max(0, x-padding), min(x+larg+padding, image_rgb.shape[1])
    face_img = image_rgb[y:height,x:width,:]
plt.imshow(copy_image_rgb)

# %%
plt.imshow(face_img)

# %% [markdown]
# ### Borrar a Imagem inteira

# %%
blured_image = cv2.GaussianBlur(image_rgb, (15,15), 20)
plt.imshow(blured_image)

# %% [markdown]
# ### Substituir Imagem Original da Face na Imagem Borrada

# %%
final_image = blured_image
final_image[y:height,x:width,:] = face_img
plt.imshow(final_image)
